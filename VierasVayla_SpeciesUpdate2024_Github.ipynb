# MX.40087	22	Putkilokasvit	Malaxis monophyllos	sääskenvalkku
# MX.40508	23	Putkilokasvit	Melica ciliata	tähkähelmikkä
# MX.40079	24	Putkilokasvit	Ophrys insectifera	kimalaisorho
# MX.40076	25	Putkilokasvit	Orchis militaris	soikkokämmekkä
# MX.38964	26	Putkilokasvit	Oxytropis lapponica	tunturikeulankärki
# MX.41754	27	Putkilokasvit	Platanthera oligantha	pikkulehdokki
# MX.38215	28	Putkilokasvit	Polygonum oxyspermum	meritatar
# MX.37888	29	Putkilokasvit	Pulsatilla patens	hämeenkylmänkukka
# MX.37886	30	Putkilokasvit	Pulsatilla vernalis	kangasvuokko
# MX.38119	31	Putkilokasvit	Silene involucrata ssp. tenella	pohjankehtoailakki
# MX.5082333	33	Putkilokasvit	Veratrum lobelianum	pohjanpärskäjuuri
# MX.38313	34	Putkilokasvit	Viola collina	mäkiorvokki
#
# There is additional data about rosa rugosa and Lupinus polyphyllus that is not displayed here because of data privacy. The data origin is Destia. This is combined with laji.fi data about rosa rugosa and Lupinus polyphyllus for a more comprehensive state of the species.

# %% [markdown]
# # Update

# %%
# Restricted data
# second code block is the identical process but for the open version, where restricted species are excluded

import geopandas as gpd
import pandas as pd
import numpy as np
import dask_geopandas as dask_gpd
import fiona

# SENSITIVES

#ensure that the open publication does not include any sensitive species listed in https://laji.fi/about/709
taxon_id_sensitives = ["MX.38825","MX.38292","MX.38294","MX.38295","MX.39280","MX.38961","MX.37732","MX.40083","MX.40374","MX.40035","MX.40036","MX.37893","MX.40028","MX.41330","MX.38147","MX.40033","MX.40031","MX.38596","MX.39296","MX.38300","MX.40286","MX.40287","MX.40085","MX.40087","MX.40508","MX.40079","MX.40076","MX.38964","MX.41754","MX.38215","MX.37888","MX.37886","MX.38119","MX.5082333","MX.38313"]
#concat the mx code with the prefix for the filter to work
taxon_id_sensitives = ["http://tun.fi/" + code for code in taxon_id_sensitives]
len(taxon_id_sensitives)

# SUBSETTING 

#data to be updated
filename = r"path\2023Version.gpkg"
ddf = dask_gpd.read_file(filename, npartitions=2)
df_ruudut = ddf.compute()

#laji.fi species observation data
#HBF_94770_geo.gpkg downloaded 30.9.2024 had 332 863 observations from 79 species (extra 35 508 observations vs 2023)
filename = r"path\HBF_94770_geo.gpkg"
ddf = dask_gpd.read_file(filename, npartitions=2)
df_lajit = ddf.compute()
len(df_lajit)

#create species_name column that includes IUCN class in addition to the species name
df_lajit['scientific_name_interpreted2'] = df_lajit.apply(lambda row: row['scientific_name_interpreted'] + ' ' + row['red_list_status'][:2] if row['red_list_status'] is not None and row['scientific_name_interpreted'] is not None else row['scientific_name_interpreted'], axis=1)
df_lajit['common_name_finnish2'] = df_lajit.apply(lambda row: row['common_name_finnish'] + ' ' + row['red_list_status'][:2] if row['red_list_status'] is not None and row['common_name_finnish'] is not None else row['common_name_finnish'], axis=1)

kurtturuusu = 'http://tun.fi/MX.38815'
df_kurtturuusu = df_lajit[df_lajit['taxon_id']==kurtturuusu]
print(len(df_kurtturuusu))

komealupiini = 'http://tun.fi/MX.38950'
df_komealupiini = df_lajit[df_lajit['taxon_id']==komealupiini]
print(len(df_komealupiini))

taxon_id_invasive = ['http://tun.fi/MX.38950','http://tun.fi/MX.38815']
condition1 = df_lajit['taxon_id'].isin(taxon_id_invasive)
df_invasive = df_lajit[condition1]
print(len(df_invasive))

#all rows except rosa and lupinus, because they already have a column assigned to them
condition1 = ~df_lajit['taxon_id'].isin(taxon_id_invasive)
df_other = df_lajit[condition1]
print(len(df_other))

#drop sensitive data. use df_notsensitive instead of df_other in open data
condition1 = ~df_other['taxon_id'].isin(taxon_id_sensitives)
df_notsensitive = df_other[condition1]
len(df_notsensitive)

print(f"total number of species observations is {len(df_lajit)}")
print(f"of which the amount of rosa rugosa and Lupinus polyphyllus observations is {len(df_invasive)}")
print(f"and the amount of other species observations is {len(df_other)}")
print(f"which is {len(df_notsensitive)} without the sensitive species observations")

# AGGREGATION AND COLUMN ADDITION

#Species observation points in polygons (grid cells), change input df according to openness and comment the other out
point_in_polygons = gpd.sjoin(df_other, df_ruudut, how='left')

# Group by polygon index and aggregate values into columns. "set" command results into unique list
df_ruudut['Havaintopisteita'] = point_in_polygons.groupby('index_right').size()
df_ruudut['AlueenLajit_SCI'] = point_in_polygons.groupby('index_right')['scientific_name_interpreted2'].apply(set)
df_ruudut['AlueenLajit_FIN'] = point_in_polygons.groupby('index_right')['common_name_finnish2'].apply(set)
df_ruudut['Uniikkilajeja'] = df_ruudut['AlueenLajit_SCI'].apply(lambda x: len(x) if not isinstance(x, float) else 0) #to overcome type error when has no len()
df_ruudut['AlueenLajit_SCI'] = df_ruudut['AlueenLajit_SCI'].astype(str).str.replace('{', '').str.replace('}', '').str.replace("'", '') #ensure that output is string and has no brackets
df_ruudut['AlueenLajit_FIN'] = df_ruudut['AlueenLajit_FIN'].astype(str).str.replace('{', '').str.replace('}', '').str.replace("'", '')

# Group by polygon index and aggregate species names into a set and observation years into lists
aggregated_data = point_in_polygons.groupby('index_right').agg({'year': list})

# Get the minimum and maximum observation year for each polygon
aggregated_data['min_year'] = aggregated_data['year'].apply(min)
aggregated_data['max_year'] = aggregated_data['year'].apply(max)

# Create a new column 'year_range' where value is 'min_year - max_year'
aggregated_data['Havaintoaika'] = aggregated_data.apply(lambda row: f"{row['min_year']} - {row['max_year']}", axis=1)

# Merge aggregated_data back into polygons
df_ruudut['Havaintoaika'] = aggregated_data['Havaintoaika'] 

#if already value 1, then keeps it, else checks overlap and adds 1 if overlap (no need to process additional data again)
df_ruudut['Komealupiini'] = df_ruudut.apply(lambda row: row['Komealupiini'] if row['Komealupiini'] == 1 
                                            else df_komealupiini['geometry'].intersects(row['geometry']).any().astype(int),axis=1)

df_ruudut['Kurtturuusu'] = df_ruudut.apply(lambda row: row['Kurtturuusu'] if row['Kurtturuusu'] == 1 
                                            else df_kurtturuusu['geometry'].intersects(row['geometry']).any().astype(int),axis=1)

#save the file
out_file = r"path\VierasVayla_20240925_sensitive.gpkg"
df_ruudut.to_file(out_file, layer='VierasVayla', driver="GPKG")
# Out:
# 10983
# 43923
# 54906
# 277957
# total number of species observations is 332863
# of which the amount of rosa rugosa and Lupinus polyphyllus observations is 54906
# and the amount of other species observations is 277957
# which is 276968 without the sensitive species observations
# FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_ruudut['AlueenLajit_SCI'] = df_ruudut['AlueenLajit_SCI'].astype(str).str.replace('{', '').str.replace('}', '').str.replace("'", '') #ensure that output is string and has no brackets
# FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_ruudut['AlueenLajit_FIN'] = df_ruudut['AlueenLajit_FIN'].astype(str).str.replace('{', '').str.replace('}', '').str.replace("'", '')

# %%
# Open data
# sensitive species excluded

import geopandas as gpd
import pandas as pd
import numpy as np
import dask_geopandas as dask_gpd
import fiona

# SENSITIVES

#ensure that the open publication does not include any sensitive species listed in https://laji.fi/about/709
taxon_id_sensitives = [
    "MX.38825",
    "MX.38292",
    "MX.38294",
    "MX.38295",
    "MX.39280",
    "MX.38961",
    "MX.37732",
    "MX.40083",
    "MX.40374",
    "MX.40035",
    "MX.40036",
    "MX.37893",
    "MX.40028",
    "MX.41330",
    "MX.38147",
    "MX.40033",
    "MX.40031",
    "MX.38596",
    "MX.39296",
    "MX.38300",
    "MX.40286",
    "MX.40287",
    "MX.40085",
    "MX.40087",
    "MX.40508",
    "MX.40079",
    "MX.40076",
    "MX.38964",
    "MX.41754",
    "MX.38215",
    "MX.37888",
    "MX.37886",
    "MX.38119",
    "MX.5082333",
    "MX.38313"
]
#concat the mx code with the prefix for the filter to work
taxon_id_sensitives = ["http://tun.fi/" + code for code in taxon_id_sensitives]
len(taxon_id_sensitives)

# SUBSETTING 

#data to be updated
filename = r"path\2023Version.gpkg"
ddf = dask_gpd.read_file(filename, npartitions=2)
df_ruudut = ddf.compute()

#laji.fi species observation data
#HBF_94770_geo.gpkg downloaded 30.9.2024 had 332 863 observations from 79 species (extra 35 508 observations vs 2023)
filename = r"path\HBF_94770_geo_gpkg\HBF_94770_geo.gpkg"
ddf = dask_gpd.read_file(filename, npartitions=2)
df_lajit = ddf.compute()
len(df_lajit)

#create species_name column that includes IUCN class in addition to the species name
df_lajit['scientific_name_interpreted2'] = df_lajit.apply(lambda row: row['scientific_name_interpreted'] + ' ' + row['red_list_status'][:2] if row['red_list_status'] is not None and row['scientific_name_interpreted'] is not None else row['scientific_name_interpreted'], axis=1)
df_lajit['common_name_finnish2'] = df_lajit.apply(lambda row: row['common_name_finnish'] + ' ' + row['red_list_status'][:2] if row['red_list_status'] is not None and row['common_name_finnish'] is not None else row['common_name_finnish'], axis=1)

kurtturuusu = 'http://tun.fi/MX.38815'
df_kurtturuusu = df_lajit[df_lajit['taxon_id']==kurtturuusu]
print(len(df_kurtturuusu))

komealupiini = 'http://tun.fi/MX.38950'
df_komealupiini = df_lajit[df_lajit['taxon_id']==komealupiini]
print(len(df_komealupiini))

taxon_id_invasive = ['http://tun.fi/MX.38950','http://tun.fi/MX.38815']
condition1 = df_lajit['taxon_id'].isin(taxon_id_invasive)
df_invasive = df_lajit[condition1]
print(len(df_invasive))

#all rows except rosa and lupinus, because they already have a column assigned to them
condition1 = ~df_lajit['taxon_id'].isin(taxon_id_invasive)
df_other = df_lajit[condition1]
print(len(df_other))

#drop sensitive data. use df_notsensitive instead of df_other in open data
condition1 = ~df_other['taxon_id'].isin(taxon_id_sensitives)
df_notsensitive = df_other[condition1]
len(df_notsensitive)

print(f"total number of species observations is {len(df_lajit)}")
print(f"of which the amount of rosa rugosa and Lupinus polyphyllus observations is {len(df_invasive)}")
print(f"and the amount of other species observations is {len(df_other)}")
print(f"which is {len(df_notsensitive)} without the sensitive species observations")

# AGGREGATION AND COLUMN ADDITION

#Species observation points in polygons (grid cells), change input df according to openness and comment the other out
point_in_polygons = gpd.sjoin(df_notsensitive, df_ruudut, how='left')

# Group by polygon index and aggregate values into columns. "set" command results into unique list
df_ruudut['Havaintopisteita'] = point_in_polygons.groupby('index_right').size()
df_ruudut['AlueenLajit_SCI'] = point_in_polygons.groupby('index_right')['scientific_name_interpreted2'].apply(set)
df_ruudut['AlueenLajit_FIN'] = point_in_polygons.groupby('index_right')['common_name_finnish2'].apply(set)
df_ruudut['Uniikkilajeja'] = df_ruudut['AlueenLajit_SCI'].apply(lambda x: len(x) if not isinstance(x, float) else 0) #to overcome type error when has no len()
df_ruudut['AlueenLajit_SCI'] = df_ruudut['AlueenLajit_SCI'].astype(str).str.replace('{', '').str.replace('}', '').str.replace("'", '') #ensure that output is string and has no brackets
df_ruudut['AlueenLajit_FIN'] = df_ruudut['AlueenLajit_FIN'].astype(str).str.replace('{', '').str.replace('}', '').str.replace("'", '')

# Group by polygon index and aggregate species names into a set and observation years into lists
aggregated_data = point_in_polygons.groupby('index_right').agg({'year': list})

# Get the minimum and maximum observation year for each polygon
aggregated_data['min_year'] = aggregated_data['year'].apply(min)
aggregated_data['max_year'] = aggregated_data['year'].apply(max)

# Create a new column 'year_range' where value is 'min_year - max_year'
aggregated_data['Havaintoaika'] = aggregated_data.apply(lambda row: f"{row['min_year']} - {row['max_year']}", axis=1)

# Merge aggregated_data back into polygons
df_ruudut['Havaintoaika'] = aggregated_data['Havaintoaika'] 

#if already value 1, then keeps it, else checks overlap and adds 1 if overlap (no need to process additional data again)
df_ruudut['Komealupiini'] = df_ruudut.apply(lambda row: row['Komealupiini'] if row['Komealupiini'] == 1 
                                            else df_komealupiini['geometry'].intersects(row['geometry']).any().astype(int),axis=1)

df_ruudut['Kurtturuusu'] = df_ruudut.apply(lambda row: row['Kurtturuusu'] if row['Kurtturuusu'] == 1 
                                            else df_kurtturuusu['geometry'].intersects(row['geometry']).any().astype(int),axis=1)

#save the file
out_file = r"path\VierasVayla_20240925_open.gpkg"

#df_ruudut.to_parquet(out_file)
df_ruudut.to_file(out_file, layer='VierasVayla', driver="GPKG")
# Out:
# 10983
# 43923
# 54906
# 277957
# total number of species observations is 332863
# of which the amount of rosa rugosa and Lupinus polyphyllus observations is 54906
# and the amount of other species observations is 277957
# which is 276968 without the sensitive species observations
# FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_ruudut['AlueenLajit_SCI'] = df_ruudut['AlueenLajit_SCI'].astype(str).str.replace('{', '').str.replace('}', '').str.replace("'", '') #ensure that output is string and has no brackets
# FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_ruudut['AlueenLajit_FIN'] = df_ruudut['AlueenLajit_FIN'].astype(str).str.replace('{', '').str.replace('}', '').str.replace("'", '')

# %% [markdown]
# # Change comparison
# old version 2023 vs new version 2024

# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import dask_geopandas as dask_gpd
import fiona

filename = r"path\2023Version.gpkg"
ddf = dask_gpd.read_file(filename, npartitions=2)
df1 = ddf.compute()
print(len(df1))
print(df1['Kurtturuusu'].value_counts())

out_file = r"path\2024Version.gpkg"
ddf = dask_gpd.read_file(out_file, npartitions=2)
df2 = ddf.compute()
print(len(df2))
print(df2['Kurtturuusu'].value_counts())

diff = df1.compare(df2) #numerical
#diff = df1.ne(df2)
print(diff)
# Out:
# 92054
# 0    88861
# 1     3193
# Name: Kurtturuusu, dtype: int64
# 92054
# 0    88646
# 1     3408
# Name: Kurtturuusu, dtype: int64
#       Komealupiini       Kurtturuusu       Havaintopisteita        \
#               self other        self other             self other
# 0              NaN   NaN         NaN   NaN             28.0  27.0
# 1              NaN   NaN         0.0   1.0             67.0  63.0
# 2              NaN   NaN         NaN   NaN              NaN   NaN
# 3              NaN   NaN         NaN   NaN              NaN   NaN
# 4              NaN   NaN         NaN   NaN              NaN   NaN
# ...            ...   ...         ...   ...              ...   ...
# 92047          NaN   NaN         NaN   NaN              NaN   1.0
# 92048          NaN   NaN         NaN   NaN              NaN   4.0
# 92051          NaN   NaN         NaN   NaN              NaN   1.0
# 92052          NaN   NaN         NaN   NaN              NaN   2.0
# 92053          NaN   NaN         NaN   NaN              NaN   1.0
#
#       Uniikkilajeja                                          AlueenLajit_FIN  \
#                self other                                               self
# 0              20.0  19.0  ahopäivänkakkara LC, ahopukinjuuri LC, huopavo...
# 1               NaN   NaN  ahopukinjuuri LC, pikkunoidanlukko EN, huopavo...
# 2              26.0  25.0  ratarusojuuri, ahopäivänkakkara LC, mali LC, h...
# 3               NaN   NaN  huopavoikeltano LC, heinäratamo LC, ketoruusur...
# 4               NaN   NaN  ketoruusuruoho LC, keltamatara VU, ahopäivänka...
# ...             ...   ...                                                ...
# 92047           0.0   1.0                                                nan
# 92048           0.0   4.0                                                nan
# 92051           0.0   1.0                                                nan
# 92052           0.0   2.0                                                nan
# 92053           0.0   1.0                                                nan
#
#                                                           \
#                                                    other
# 0      keltamatara VU, ketoruusuruoho LC, mäkikuisma ...
# 1      keltamatara VU, ketoruusuruoho LC, mäkikuisma ...
# 2      keltamatara VU, ketoruusuruoho LC, peurankello...
# 3      niittynätkelmä LC, heinäratamo LC, huopavoikel...
# 4      heinäratamo LC, rohtokoirankieli EN, keltamata...
# ...                                                  ...
# 92047                                  ketoruusuruoho LC
# 92048  niittynätkelmä LC, kesämaitiainen NT, peuranke...
# 92051                                 ahokissankäpälä NT
# 92052                   kesämaitiainen NT, puna-apila LC
# 92053                                ahopäivänkakkara LC
#
#                                          AlueenLajit_SCI  \
#                                                     self
# 0      Trifolium arvense LC, Veronica spicata LC, Sax...
# 1      Trifolium arvense LC, Veronica spicata LC, Sax...
# 2      Trifolium arvense LC, Veronica spicata LC, Sax...
# 3      Pilosella officinarum LC, Plantago lanceolata ...
# 4      Knautia arvensis LC, Plantago lanceolata LC, P...
# ...                                                  ...
# 92047                                                nan
# 92048                                                nan
# 92051                                                nan
# 92052                                                nan
# 92053                                                nan
#
#                                                              Havaintoaika  \
#                                                    other             self
# 0      Galium verum VU, Saxifraga tridactylites NT, H...              NaN
# 1      Cerastium glutinosum NT, Centaurea jacea LC, G...  1998.0 - 2022.0
# 2      Cerastium glutinosum NT, Centaurea jacea LC, G...  1990.0 - 2022.0
# 3      Plantago lanceolata LC, Lathyrus pratensis LC,...              NaN
# 4      Centaurea jacea LC, Artemisia absinthium LC, F...              NaN
# ...                                                  ...              ...
# 92047                                Knautia arvensis LC             None
# 92048  Lathyrus pratensis LC, Campanula glomerata LC,...             None
# 92051                               Antennaria dioica NT             None
# 92052       Leontodon hispidus NT, Trifolium pratense LC             None
# 92053                            Leucanthemum vulgare LC             None
#
#
#                  other
# 0                  NaN
# 1      2002.0 - 2022.0
# 2      1990.0 - 2024.0
# 3                  NaN
# 4                  NaN
# ...                ...
# 92047  2023.0 - 2023.0
# 92048  2023.0 - 2023.0
# 92051  2023.0 - 2023.0
# 92052  2023.0 - 2023.0
# 92053  2023.0 - 2023.0
#
# [22377 rows x 14 columns]

# %%
print(df1['Havaintopisteita'].describe())
df2['Havaintopisteita'].describe()
# Out:
# count    32531.000000
# mean         5.294796
# std          9.382127
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          6.000000
# max        301.000000
# Name: Havaintopisteita, dtype: float64
# count    34774.000000
# mean         5.484155
# std          9.989343
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          6.000000
# max        301.000000
# Name: Havaintopisteita, dtype: float64

# %%
# Specify the column to compare
column_to_compare = 'Havaintopisteita'

# Create a comparison DataFrame
comparison_df = pd.DataFrame({
    'Before': df1[column_to_compare],
    'After': df2[column_to_compare]
})

# Filter rows where values have changed
comparison_df = comparison_df[comparison_df['Before'] != comparison_df['After']].dropna()

print(comparison_df)
# Out:
#        Before  After
# 0        28.0   27.0
# 1        67.0   63.0
# 17        1.0    3.0
# 19        1.0    3.0
# 23        2.0   20.0
# ...       ...    ...
# 92027     9.0   12.0
# 92028    22.0   43.0
# 92033     4.0    6.0
# 92034     2.0    5.0
# 92046     8.0    9.0
#
# [2864 rows x 2 columns]
